# %%
#This calls pandas and seaborn as well as a graph plotting extension 

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#This finds the file that I want. I've put the file in the same folder as the python document.
# !head ERKTR2hrs.csv
# Out:
# A375P screen test 110417,1894,Screen test CyclinA pRB,2877,2017-04-11T11:00:18Z,29528,Binimetinib,MEK,J15,10,15,18,1,1,35,132,419,"[91,393,155,448]",1,0,0,-0.362525,C,0.0212034,0.00341204,0.335716,0.0219379,0.0377577,0.39814,0.204296,0.156013,0.0740172,0.117646,0.0884589,0.136923,0.117078,0.0924927,0.0194796,0.00276959,0.381013,0.0313451,0.0285316,0.629348,0.170194,0.13458,0.0623736,0.102624,0.0771353,0.115164,0.0929472,0.0784519,0.337917,0.0137399,0.0333618,0.24424,0.220919,393.407,0.414054,43.6783,18.0852,0.494185,668.333,0.662589,17.5466,11.6262,0.878816,184.814,34.86,30.4332,32.3402,193.496,396.354,18.7743,55.5688,45,0.488189854444744927428616434983397702/Tyr204) SER Saddle 0 px,Nucleus PhosphoERK (Thr202/Tyr204) SER Valley 0 px,Nucleus PhosphoERK (Thr202/Tyr204) SER Ridge 0 px,Nucleus PhosphoERK (Thr202/Tyr204) SER Edge 0 px,Nucleus PhosphoERK (Thr202/Tyr204) SER Hole 0 px,Nucleus PhosphoERK (Thr202/Tyr204) SER Spot 0 px,Cell PhosphoERK (Thr202/Tyr204) Gabor Max 2 px w2,Cell Pho
# ...

# %%
#The file is converted into a dataframe and can now be read by python. 
#There are some ERKTR values that didn't get calculated - the na values tells pandas to ignore them.
#df = pd.read_csv("ERKTR2hrs.csv", na_values=['#VALUE!'])

df = pd.read_csv("ERKTR2hrs.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-95a3b8580512> in <module>()
#       3 #df = pd.read_csv("ERKTR2hrs.csv", na_values=['#VALUE!'])
#       4
# ----> 5 df = pd.read_csv("ERKTR2hrs.csv")
#       6 df
#
# NameError: name 'pd' is not defined

# %%
#describes the table held in df - you can call the df something specific if you want,
#for now I will only have one df so i'll just keep it as df
df.describe()
# Out:
#        ScreenID  PlateID  MeasurementID           Row        Column  \
# count   13302.0  13302.0        13302.0  13302.000000  13302.000000
# mean     1894.0   2877.0        29528.0      9.499248     12.443768
# std         0.0      0.0            0.0      0.500018      1.734749
# min      1894.0   2877.0        29528.0      9.000000     10.000000
# 25%      1894.0   2877.0        29528.0      9.000000     11.000000
# 50%      1894.0   2877.0        29528.0      9.000000     12.000000
# 75%      1894.0   2877.0        29528.0     10.000000     14.000000
# max      1894.0   2877.0        29528.0     10.000000     15.000000
#
#               Field    Plane  Timepoint  Object Number             X  \
# count  13302.000000  13302.0    13302.0   13302.000000  13302.000000
# mean       9.735077      1.0        1.0      38.799579    320.456097
# std        4.893286      0.0        0.0      28.588765    170.596470
# min        1.000000      1.0        1.0       1.000000     16.000000
# ...

# %%
df.head()
# Out:
#                  ScreenName  ScreenID                PlateName  PlateID  \
# 0  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
# 1  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
# 2  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
# 3  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
# 4  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
#
#         MeasurementDate  MeasurementID Drug Name  Drug Target WellName  Row  \
# 0  2017-04-11T11:00:18Z          29528       DMSO        None      I10    9
# 1  2017-04-11T11:00:18Z          29528       DMSO        None      I10    9
# 2  2017-04-11T11:00:18Z          29528       DMSO        None      I10    9
# 3  2017-04-11T11:00:18Z          29528       DMSO        None      I10    9
# 4  2017-04-11T11:00:18Z          29528       DMSO        None      I10    9
#
# ...

# %%
df.tail()
# Out:
#                      ScreenName  ScreenID                PlateName  PlateID  \
# 13297  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
# 13298  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
# 13299  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
# 13300  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
# 13301  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
#
#             MeasurementDate  MeasurementID   Drug Name  Drug Target WellName  \
# 13297  2017-04-11T11:00:18Z          29528  Binimetinib         MEK      J15
# 13298  2017-04-11T11:00:18Z          29528  Binimetinib         MEK      J15
# 13299  2017-04-11T11:00:18Z          29528  Binimetinib         MEK      J15
# 13300  2017-04-11T11:00:18Z          29528  Binimetinib         MEK      J15
# 13301  2017-04-11T11:00:18Z          29528  Binimetinib         MEK      J15
#
#        Row    ...      Nucleus Area  \
# ...

# %%
df['ERKTR C/N']
# Out:
# 0        0.980528
# 1        0.780866
# 2        0.788143
# 3        0.786300
# 4        0.732223
# 5        1.040565
# 6        0.751504
# 7        1.172724
# 8        0.753594
# 9        1.152352
# 10       0.756165
# 11       1.076867
# 12       1.098094
# 13       0.810734
# 14       1.176128
# 15       1.064447
# 16       0.928725
# 17       0.413243
# 18       1.035849
# 19       1.150060
# 20       0.897884
# 21       1.035195
# 22       1.226413
# 23       0.852506
# 24       1.510590
# 25       0.991319
# 26       1.207474
# 27       1.189162
# 28       1.300176
# 29       1.216586
#            ...
# 13272    1.034706
# 13273    0.614803
# 13274    0.344472
# 13275    0.746566
# 13276    0.689179
# 13277    1.063572
# 13278    0.838548
# 13279    0.648316
# 13280    0.362652
# 13281    0.381449
# 13282    0.843647
# 13283    0.438686
# 13284    0.823021
# 13285    0.496605
# 13286    1.868453
# 13287    1.098496
# 13288    0.902117
# 13289    0.861834
# 13290    0.819399
# ...

# %%
df.dtypes
# Out:
# ScreenName                                                        object
# ScreenID                                                           int64
# PlateName                                                         object
# PlateID                                                            int64
# MeasurementDate                                                   object
# MeasurementID                                                      int64
# Drug Name                                                         object
# Drug Target                                                       object
# WellName                                                          object
# Row                                                                int64
# Column                                                             int64
# Field                                                              int64
# Plane                                                              int64
# ...

# %%
# %matplotlib inline
plt.figure(figsize=(16,8))
sns.distplot(df['ERKTR C/N'].dropna(),
            )
# Out:
# /Users/csimpson/anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
DMSO = df[df['Drug Target'] == "None"].head()
BRAF = df[df['Drug Target'] == 'BRAF'].head()
MEK = df[df['Drug Target'] == 'MEK'].head()

DMSO
# Out:
#                  ScreenName  ScreenID                PlateName  PlateID  \
# 0  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
# 1  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
# 2  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
# 3  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
# 4  A375P screen test 110417      1894  Screen test CyclinA pRB     2877
#
#         MeasurementDate  MeasurementID Drug Name  Drug Target WellName  Row  \
# 0  2017-04-11T11:00:18Z          29528       DMSO        None      I10    9
# 1  2017-04-11T11:00:18Z          29528       DMSO        None      I10    9
# 2  2017-04-11T11:00:18Z          29528       DMSO        None      I10    9
# 3  2017-04-11T11:00:18Z          29528       DMSO        None      I10    9
# 4  2017-04-11T11:00:18Z          29528       DMSO        None      I10    9
#
# ...

# %%
# %matplotlib inline
plt.figure(figsize=(16,8))
sns.distplot(DMSO['ERKTR C/N'].dropna())
# Out:
# /Users/csimpson/anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# %matplotlib inline
plt.figure(figsize=(16,8))
sns.distplot(BRAF['ERKTR C/N'].dropna())
# Out:
# /Users/csimpson/anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# %matplotlib inline
sns.set_style("whitegrid")
plt.figure(figsize=(16,8))

sns.factorplot(
    data=df, 
    kind='box', 
    x='Drug Target', 
    y='ERKTR C/N', 
    size=7, 
    aspect=1.6, # make it twice as wide as high
    palette='Set1' # use a nice categorical colour scheme
)

# %%
# %matplotlib inline

plt.figure(figsize=(16,8))

sns.factorplot(
    data=df, 
    kind='box', 
    x='Drug Target', 
    y = 'Intensity Ring Region PhosphoERK (Thr202/Tyr204)', 
    size=7, 
    aspect=1.6, # make it twice as wide as high
    palette='Set1' # use a nice categorical colour scheme
)
